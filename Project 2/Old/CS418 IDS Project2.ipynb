# %%
import pandas as pd

# %%
merged = pd.read_csv("merged.csv")
merged.head()
# Out:
#    Unnamed: 0 State    County  Democratic  Republican  FIPS  Total Population  \
# 0           0    AZ    apache     16298.0      7810.0  4001             72346
# 1           1    AZ   cochise     17383.0     26929.0  4003            128177
# 2           2    AZ  coconino     34240.0     19249.0  4005            138064
# 3           3    AZ      gila      7643.0     12180.0  4007             53179
# 4           4    AZ    graham      3368.0      6870.0  4009             37529
#
#    Citizen Voting-Age Population  Percent White, not Hispanic or Latino  \
# 0                            NaN                              18.571863
# 1                        92915.0                              56.299492
# 2                       104265.0                              54.619597
# 3                            NaN                              63.222325
# 4                            NaN                              51.461536
#
#    Percent Black, not Hispanic or Latino  ...  Percent Unemployed  \
# 0                               0.486551  ...           15.807433
# 1                               3.714395  ...            8.567108
# 2                               1.342855  ...            8.238305
# 3                               0.552850  ...           12.129932
# 4                               1.811932  ...           14.424104
#
#    Percent Less than High School Degree  Percent Less than Bachelor's Degree  \
# 0                             21.758252                            88.941063
# 1                             13.409171                            76.837055
# 2                             11.085381                            65.791439
# 3                             15.729958                            82.262624
# 4                             14.580797                            86.675944
#
#    Percent Rural  Party  Percent Age between 30 and 64 inclusive  \
# 0      74.061076   Demo                                40.823266
# 1      36.301067    Rep                                42.341450
# 2      31.466066   Demo                                40.179917
# 3      41.062000    Rep                                41.364072
# 4      46.437399    Rep                                41.290735
#
#    Percent Male  Percent more than High School Degree  \
# 0     49.401487                             78.241748
# 1     50.930354                             86.590829
# 2     49.418386                             88.914619
# 3     49.703830                             84.270042
# 4     53.686482                             85.419203
#
#    Percent more than Bachelor's Degree  Citizen Voting-Age Population voted
# 0                            11.058937                              24108.0
# 1                            23.162945                              44312.0
# 2                            34.208561                              53489.0
# 3                            17.737376                              19823.0
# 4                            13.324056                              10238.0
#
# [5 rows x 26 columns]

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 26 columns):
# Unnamed: 0                                 1200 non-null int64
# State                                      1200 non-null object
# County                                     1200 non-null object
# Democratic                                 1200 non-null float64
# Republican                                 1200 non-null float64
# FIPS                                       1200 non-null int64
# Total Population                           1200 non-null int64
# Citizen Voting-Age Population              520 non-null float64
# Percent White, not Hispanic or Latino      1200 non-null float64
# Percent Black, not Hispanic or Latino      1200 non-null float64
# Percent Hispanic or Latino                 1200 non-null float64
# Percent Foreign Born                       1200 non-null float64
# Percent Female                             1200 non-null float64
# Percent Age 29 and Under                   1200 non-null float64
# Percent Age 65 and Older                   1200 non-null float64
# Median Household Income                    1200 non-null int64
# Percent Unemployed                         1200 non-null float64
# Percent Less than High School Degree       1200 non-null float64
# Percent Less than Bachelor's Degree        1200 non-null float64
# Percent Rural                              1200 non-null float64
# Party                                      1200 non-null object
# Percent Age between 30 and 64 inclusive    1200 non-null float64
# Percent Male                               1200 non-null float64
# Percent more than High School Degree       1200 non-null float64
# Percent more than Bachelor's Degree        1200 non-null float64
# Citizen Voting-Age Population voted        1200 non-null float64
# dtypes: float64(19), int64(4), object(3)
# memory usage: 243.8+ KB

# %%
merged = merged.drop(["Unnamed: 0","Citizen Voting-Age Population", "Citizen Voting-Age Population voted", "Percent Male", "Percent Age between 30 and 64 inclusive", "Percent more than High School Degree"], axis = 1)

# %%
merged = merged[(merged[["Democratic", "Republican"]] != 0).all(axis = 1)]

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1195 entries, 0 to 1199
# Data columns (total 20 columns):
# State                                    1195 non-null object
# County                                   1195 non-null object
# Democratic                               1195 non-null float64
# Republican                               1195 non-null float64
# FIPS                                     1195 non-null int64
# Total Population                         1195 non-null int64
# Percent White, not Hispanic or Latino    1195 non-null float64
# Percent Black, not Hispanic or Latino    1195 non-null float64
# Percent Hispanic or Latino               1195 non-null float64
# Percent Foreign Born                     1195 non-null float64
# Percent Female                           1195 non-null float64
# Percent Age 29 and Under                 1195 non-null float64
# Percent Age 65 and Older                 1195 non-null float64
# Median Household Income                  1195 non-null int64
# Percent Unemployed                       1195 non-null float64
# Percent Less than High School Degree     1195 non-null float64
# Percent Less than Bachelor's Degree      1195 non-null float64
# Percent Rural                            1195 non-null float64
# Party                                    1195 non-null object
# Percent more than Bachelor's Degree      1195 non-null float64
# dtypes: float64(14), int64(3), object(3)
# memory usage: 196.1+ KB

# %%
merged2 = pd.read_csv("merged_train.csv")
merged2.head()
# Out:
#   State    County  FIPS  Total Population  \
# 0    AZ    apache  4001             72346
# 1    AZ   cochise  4003            128177
# 2    AZ  coconino  4005            138064
# 3    AZ      gila  4007             53179
# 4    AZ    graham  4009             37529
#
#    Percent White, not Hispanic or Latino  \
# 0                              18.571863
# 1                              56.299492
# 2                              54.619597
# 3                              63.222325
# 4                              51.461536
#
#    Percent Black, not Hispanic or Latino  Percent Hispanic or Latino  \
# 0                               0.486551                    5.947806
# 1                               3.714395                   34.403208
# 2                               1.342855                   13.711033
# 3                               0.552850                   18.548675
# 4                               1.811932                   32.097844
#
#    Percent Foreign Born  Percent Female  Percent Age 29 and Under  \
# 0              1.719515       50.598513                 45.854643
# 1             11.458374       49.069646                 37.902276
# 2              4.825298       50.581614                 48.946141
# 3              4.249798       50.296170                 32.238290
# 4              4.385942       46.313518                 46.393456
#
#    Percent Age 65 and Older  Median Household Income  Percent Unemployed  \
# 0                 13.322091                    32460           15.807433
# 1                 19.756275                    45383            8.567108
# 2                 10.873943                    51106            8.238305
# 3                 26.397638                    40593           12.129932
# 4                 12.315809                    47422           14.424104
#
#    Percent Less than High School Degree  Percent Less than Bachelor's Degree  \
# 0                             21.758252                            88.941063
# 1                             13.409171                            76.837055
# 2                             11.085381                            65.791439
# 3                             15.729958                            82.262624
# 4                             14.580797                            86.675944
#
#    Percent Rural  Democratic  Republican  Party
# 0      74.061076       16298        7810      1
# 1      36.301067       17383       26929      0
# 2      31.466066       34240       19249      1
# 3      41.062000        7643       12180      0
# 4      46.437399        3368        6870      0

# %%
merged2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1195 entries, 0 to 1194
# Data columns (total 19 columns):
# State                                    1195 non-null object
# County                                   1195 non-null object
# FIPS                                     1195 non-null int64
# Total Population                         1195 non-null int64
# Percent White, not Hispanic or Latino    1195 non-null float64
# Percent Black, not Hispanic or Latino    1195 non-null float64
# Percent Hispanic or Latino               1195 non-null float64
# Percent Foreign Born                     1195 non-null float64
# Percent Female                           1195 non-null float64
# Percent Age 29 and Under                 1195 non-null float64
# Percent Age 65 and Older                 1195 non-null float64
# Median Household Income                  1195 non-null int64
# Percent Unemployed                       1195 non-null float64
# Percent Less than High School Degree     1195 non-null float64
# Percent Less than Bachelor's Degree      1195 non-null float64
# Percent Rural                            1195 non-null float64
# Democratic                               1195 non-null int64
# Republican                               1195 non-null int64
# Party                                    1195 non-null int64
# dtypes: float64(11), int64(6), object(2)
# memory usage: 177.5+ KB

# %%
from sklearn.model_selection import train_test_split, KFold, cross_val_score

# %%
merged.columns
# Out:
# Index(['State', 'County', 'Democratic', 'Republican', 'FIPS',
#        'Total Population', 'Percent White, not Hispanic or Latino',
#        'Percent Black, not Hispanic or Latino', 'Percent Hispanic or Latino',
#        'Percent Foreign Born', 'Percent Female', 'Percent Age 29 and Under',
#        'Percent Age 65 and Older', 'Median Household Income',
#        'Percent Unemployed', 'Percent Less than High School Degree',
#        'Percent Less than Bachelor's Degree', 'Percent Rural', 'Party',
#        'Percent more than Bachelor's Degree'],
#       dtype='object')

# %%
merged = merged[["State", "County", "FIPS",
       "Total Population", "Percent White, not Hispanic or Latino",
       "Percent Black, not Hispanic or Latino", "Percent Hispanic or Latino",
       "Percent Foreign Born", "Percent Female", "Percent Age 29 and Under",
       "Percent Age 65 and Older", "Median Household Income",
       "Percent Unemployed", "Percent Less than High School Degree",
       "Percent Less than Bachelor's Degree", "Percent more than Bachelor's Degree", 
       "Percent Rural",
       "Democratic", "Republican", "Party"]]

# %%
merged.head()
# Out:
#   State    County  FIPS  Total Population  \
# 0    AZ    apache  4001             72346
# 1    AZ   cochise  4003            128177
# 2    AZ  coconino  4005            138064
# 3    AZ      gila  4007             53179
# 4    AZ    graham  4009             37529
#
#    Percent White, not Hispanic or Latino  \
# 0                              18.571863
# 1                              56.299492
# 2                              54.619597
# 3                              63.222325
# 4                              51.461536
#
#    Percent Black, not Hispanic or Latino  Percent Hispanic or Latino  \
# 0                               0.486551                    5.947806
# 1                               3.714395                   34.403208
# 2                               1.342855                   13.711033
# 3                               0.552850                   18.548675
# 4                               1.811932                   32.097844
#
#    Percent Foreign Born  Percent Female  Percent Age 29 and Under  \
# 0              1.719515       50.598513                 45.854643
# 1             11.458374       49.069646                 37.902276
# 2              4.825298       50.581614                 48.946141
# 3              4.249798       50.296170                 32.238290
# 4              4.385942       46.313518                 46.393456
#
#    Percent Age 65 and Older  Median Household Income  Percent Unemployed  \
# 0                 13.322091                    32460           15.807433
# 1                 19.756275                    45383            8.567108
# 2                 10.873943                    51106            8.238305
# 3                 26.397638                    40593           12.129932
# 4                 12.315809                    47422           14.424104
#
#    Percent Less than High School Degree  Percent Less than Bachelor's Degree  \
# 0                             21.758252                            88.941063
# 1                             13.409171                            76.837055
# 2                             11.085381                            65.791439
# 3                             15.729958                            82.262624
# 4                             14.580797                            86.675944
#
#    Percent more than Bachelor's Degree  Percent Rural  Democratic  Republican  \
# 0                            11.058937      74.061076     16298.0      7810.0
# 1                            23.162945      36.301067     17383.0     26929.0
# 2                            34.208561      31.466066     34240.0     19249.0
# 3                            17.737376      41.062000      7643.0     12180.0
# 4                            13.324056      46.437399      3368.0      6870.0
#
#   Party
# 0  Demo
# 1   Rep
# 2  Demo
# 3   Rep
# 4   Rep

# %%
#X = merged.iloc[:,:17]

#Y = merged.iloc[:,17:19]

# %%
# TASK 1
X_train, X_val= train_test_split(merged, test_size = 0.2, random_state = 42)

# %%
# TASK 1
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 956 entries, 943 to 1131
# Data columns (total 20 columns):
# State                                    956 non-null object
# County                                   956 non-null object
# FIPS                                     956 non-null int64
# Total Population                         956 non-null int64
# Percent White, not Hispanic or Latino    956 non-null float64
# Percent Black, not Hispanic or Latino    956 non-null float64
# Percent Hispanic or Latino               956 non-null float64
# Percent Foreign Born                     956 non-null float64
# Percent Female                           956 non-null float64
# Percent Age 29 and Under                 956 non-null float64
# Percent Age 65 and Older                 956 non-null float64
# Median Household Income                  956 non-null int64
# Percent Unemployed                       956 non-null float64
# Percent Less than High School Degree     956 non-null float64
# Percent Less than Bachelor's Degree      956 non-null float64
# Percent more than Bachelor's Degree      956 non-null float64
# Percent Rural                            956 non-null float64
# Democratic                               956 non-null float64
# Republican                               956 non-null float64
# Party                                    956 non-null object
# dtypes: float64(14), int64(3), object(3)
# memory usage: 156.8+ KB

# %%
# TASK 1
X_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239 entries, 637 to 869
# Data columns (total 20 columns):
# State                                    239 non-null object
# County                                   239 non-null object
# FIPS                                     239 non-null int64
# Total Population                         239 non-null int64
# Percent White, not Hispanic or Latino    239 non-null float64
# Percent Black, not Hispanic or Latino    239 non-null float64
# Percent Hispanic or Latino               239 non-null float64
# Percent Foreign Born                     239 non-null float64
# Percent Female                           239 non-null float64
# Percent Age 29 and Under                 239 non-null float64
# Percent Age 65 and Older                 239 non-null float64
# Median Household Income                  239 non-null int64
# Percent Unemployed                       239 non-null float64
# Percent Less than High School Degree     239 non-null float64
# Percent Less than Bachelor's Degree      239 non-null float64
# Percent more than Bachelor's Degree      239 non-null float64
# Percent Rural                            239 non-null float64
# Democratic                               239 non-null float64
# Republican                               239 non-null float64
# Party                                    239 non-null object
# dtypes: float64(14), int64(3), object(3)
# memory usage: 39.2+ KB

# %%
# TASK 2
from sklearn.preprocessing import MinMaxScaler

# %%
# TASK 2
scaler = MinMaxScaler(feature_range=(0, 1))
X_train[["Total Population", "Percent White, not Hispanic or Latino",
       "Percent Black, not Hispanic or Latino", "Percent Hispanic or Latino",
       "Percent Foreign Born", "Percent Female", "Percent Age 29 and Under",
       "Percent Age 65 and Older", "Median Household Income",
       "Percent Unemployed", "Percent Less than High School Degree",
       "Percent Less than Bachelor's Degree", "Percent more than Bachelor's Degree", 
       "Percent Rural"]] = scaler.fit_transform(X_train[["Total Population", "Percent White, not Hispanic or Latino",
       "Percent Black, not Hispanic or Latino", "Percent Hispanic or Latino",
       "Percent Foreign Born", "Percent Female", "Percent Age 29 and Under",
       "Percent Age 65 and Older", "Median Household Income",
       "Percent Unemployed", "Percent Less than High School Degree",
       "Percent Less than Bachelor's Degree", "Percent more than Bachelor's Degree", 
       "Percent Rural"]])
X_val[["Total Population", "Percent White, not Hispanic or Latino",
       "Percent Black, not Hispanic or Latino", "Percent Hispanic or Latino",
       "Percent Foreign Born", "Percent Female", "Percent Age 29 and Under",
       "Percent Age 65 and Older", "Median Household Income",
       "Percent Unemployed", "Percent Less than High School Degree",
       "Percent Less than Bachelor's Degree", "Percent more than Bachelor's Degree", 
       "Percent Rural"]] = scaler.fit_transform(X_val[["Total Population", "Percent White, not Hispanic or Latino",
       "Percent Black, not Hispanic or Latino", "Percent Hispanic or Latino",
       "Percent Foreign Born", "Percent Female", "Percent Age 29 and Under",
       "Percent Age 65 and Older", "Median Household Income",
       "Percent Unemployed", "Percent Less than High School Degree",
       "Percent Less than Bachelor's Degree", "Percent more than Bachelor's Degree", 
       "Percent Rural"]])
# Out:
# C:\Users\kalya\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\kalya\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\kalya\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\kalya\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# TASK 2
X_train.head()
# Out:
#      State       County   FIPS  Total Population  \
# 943     UT         utah  49049          0.127217
# 546     NY      wyoming  36121          0.009283
# 76      IN        allen  18003          0.082425
# 1081    WA      spokane  53063          0.109554
# 138     IN  vanderburgh  18163          0.040958
#
#       Percent White, not Hispanic or Latino  \
# 943                                0.831940
# 546                                0.899417
# 76                                 0.744931
# 1081                               0.855343
# 138                                0.842559
#
#       Percent Black, not Hispanic or Latino  Percent Hispanic or Latino  \
# 943                                0.008123                    0.116803
# 546                                0.080686                    0.033575
# 76                                 0.177175                    0.073946
# 1081                               0.026860                    0.054200
# 138                                0.139796                    0.025940
#
#       Percent Foreign Born  Percent Female  Percent Age 29 and Under  \
# 943               0.187552        0.691948                  0.844780
# 546               0.048458        0.522483                  0.420575
# 76                0.171025        0.765534                  0.551906
# 1081              0.148085        0.731634                  0.514611
# 138               0.071121        0.783432                  0.507790
#
#       Percent Age 65 and Older  Median Household Income  Percent Unemployed  \
# 943                   0.015826                 0.412808            0.260061
# 546                   0.286049                 0.310312            0.380198
# 76                    0.208555                 0.271664            0.375473
# 1081                  0.260479                 0.281005            0.385375
# 138                   0.278904                 0.211721            0.304996
#
#       Percent Less than High School Degree  \
# 943                               0.080059
# 546                               0.197224
# 76                                0.174002
# 1081                              0.091781
# 138                               0.161710
#
#       Percent Less than Bachelor's Degree  \
# 943                              0.502649
# 546                              0.830056
# 76                               0.654997
# 1081                             0.635576
# 138                              0.689905
#
#       Percent more than Bachelor's Degree  Percent Rural  Democratic  \
# 943                              0.497351       0.033270     28856.0
# 546                              0.169944       0.640826      3766.0
# 76                               0.345003       0.118797     55903.0
# 1081                             0.364424       0.136717    112000.0
# 138                              0.310095       0.091673     27183.0
#
#       Republican Party
# 943     135240.0   Rep
# 546       7553.0   Rep
# 76       65927.0   Rep
# 1081    115508.0   Rep
# 138      29375.0   Rep

# %%
# TASK 3a
from sklearn import linear_model
import statsmodels.api as sm

# %%
# TASK 3a
# Evaluate model with one predictor

#model = linear_model.LinearRegression().fit(X = X_train["Total Population"], y = Y_train["Democratic"])
#score_train = model.score(X = X_train["Total Population"], y = Y_train["Democratic"]) # R squared (training)
#score_val = model.score(X = X_train["Total Population"], y = Y_train["Democratic"]) # R squared (validation)
##score_test = model.score(X = X_test[['total_bill', 'size']], y = Y_test) # R squared (test)
#print([score_train, score_val])

# %%
# TASK 3a
# Build model with 1 predictor (using statsmodels)
X = X_train["Total Population"] 
Y = X_train["Democratic"]
X = sm.add_constant(X)
results = sm.OLS(Y,X).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Democratic   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     6222.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:29:06   Log-Likelihood:                -11135.
# No. Observations:                 956   AIC:                         2.227e+04
# Df Residuals:                     954   BIC:                         2.228e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             -387.6897    957.637     -0.405      0.686   -2267.008    1491.628
# Total Population  9.498e+05    1.2e+04     78.882      0.000    9.26e+05    9.73e+05
# ==============================================================================
# Omnibus:                     1510.514   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1309210.405
# Skew:                           9.176   Prob(JB):                         0.00
# Kurtosis:                     183.362   Cond. No.                         13.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# TASK 3a
# Build model with 2 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino"]]
Y = X_train["Democratic"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Democratic   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     3109.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:32:34   Log-Likelihood:                -11135.
# No. Observations:                 956   AIC:                         2.228e+04
# Df Residuals:                     953   BIC:                         2.229e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                 -2010.6139   3860.638     -0.521      0.603   -9586.948    5565.720
# Total Population                       9.514e+05   1.26e+04     75.536      0.000    9.27e+05    9.76e+05
# Percent White, not Hispanic or Latino  1999.4354   4607.512      0.434      0.664   -7042.605     1.1e+04
# ==============================================================================
# Omnibus:                     1508.385   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1303645.179
# Skew:                           9.149   Prob(JB):                         0.00
# Kurtosis:                     182.980   Cond. No.                         18.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# TASK 3a
# Build model with 2 predictors (using statsmodels)
X = X_train[["Total Population", "Percent Black, not Hispanic or Latino"]]
Y = X_train["Democratic"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Democratic   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     3117.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:39:40   Log-Likelihood:                -11134.
# No. Observations:                 956   AIC:                         2.227e+04
# Df Residuals:                     953   BIC:                         2.229e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                 -1124.0731   1062.879     -1.058      0.291   -3209.927     961.780
# Total Population                       9.451e+05   1.24e+04     76.254      0.000    9.21e+05    9.69e+05
# Percent Black, not Hispanic or Latino   1.01e+04   6346.869      1.591      0.112   -2355.003    2.26e+04
# ==============================================================================
# Omnibus:                     1523.786   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1350890.961
# Skew:                           9.340   Prob(JB):                         0.00
# Kurtosis:                     186.207   Cond. No.                         14.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# TASK 3a
# Build model with 2 predictors (using statsmodels)
X = X_train[["Total Population", "Percent Less than Bachelor's Degree"]]
Y = X_train["Democratic"]
X = sm.add_constant(X)
results4 = sm.OLS(Y,X).fit()
print(results4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Democratic   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     3426.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:35:58   Log-Likelihood:                -11094.
# No. Observations:                 956   AIC:                         2.219e+04
# Df Residuals:                     953   BIC:                         2.221e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                4.899e+04   5449.268      8.991      0.000    3.83e+04    5.97e+04
# Total Population                      9.06e+05   1.25e+04     72.542      0.000    8.82e+05    9.31e+05
# Percent Less than Bachelor's Degree -6.523e+04   7095.558     -9.194      0.000   -7.92e+04   -5.13e+04
# ==============================================================================
# Omnibus:                     1548.421   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1405331.523
# Skew:                           9.660   Prob(JB):                         0.00
# Kurtosis:                     189.834   Cond. No.                         19.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# TASK 3a
# Build model with 3 predictors (using statsmodels)
X = X_train[["Total Population", "Percent Less than Bachelor's Degree", "Percent Hispanic or Latino"]]
Y = X_train["Democratic"]
X = sm.add_constant(X)
results5 = sm.OLS(Y,X).fit()
print(results5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Democratic   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     2287.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:40:27   Log-Likelihood:                -11093.
# No. Observations:                 956   AIC:                         2.219e+04
# Df Residuals:                     952   BIC:                         2.221e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                4.866e+04   5450.750      8.928      0.000     3.8e+04    5.94e+04
# Total Population                     9.097e+05   1.27e+04     71.479      0.000    8.85e+05    9.35e+05
# Percent Less than Bachelor's Degree -6.377e+04   7161.692     -8.904      0.000   -7.78e+04   -4.97e+04
# Percent Hispanic or Latino          -7955.0483   5431.809     -1.465      0.143   -1.86e+04    2704.655
# ==============================================================================
# Omnibus:                     1546.991   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1402275.696
# Skew:                           9.641   Prob(JB):                         0.00
# Kurtosis:                     189.633   Cond. No.                         19.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# TASK 3a
# Build model with 3 predictors (using statsmodels)
X = X_train[["Total Population", "Percent Less than Bachelor's Degree", "Percent Foreign Born"]]
Y = X_train["Democratic"]
X = sm.add_constant(X)
results5 = sm.OLS(Y,X).fit()
print(results5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Democratic   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     2287.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:41:18   Log-Likelihood:                -11093.
# No. Observations:                 956   AIC:                         2.219e+04
# Df Residuals:                     952   BIC:                         2.221e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                4.626e+04   5802.354      7.973      0.000    3.49e+04    5.77e+04
# Total Population                     8.983e+05   1.37e+04     65.589      0.000    8.71e+05    9.25e+05
# Percent Less than Bachelor's Degree  -6.29e+04   7295.033     -8.623      0.000   -7.72e+04   -4.86e+04
# Percent Foreign Born                 9057.1379   6631.342      1.366      0.172   -3956.600    2.21e+04
# ==============================================================================
# Omnibus:                     1551.483   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1409800.224
# Skew:                           9.701   Prob(JB):                         0.00
# Kurtosis:                     190.126   Cond. No.                         20.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# TASK 3a
# Build model with 3 predictors (using statsmodels)
X = X_train[["Total Population", "Percent Less than Bachelor's Degree", "Percent Female"]]
Y = X_train["Democratic"]
X = sm.add_constant(X)
results5 = sm.OLS(Y,X).fit()
print(results5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Democratic   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     2282.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:41:51   Log-Likelihood:                -11094.
# No. Observations:                 956   AIC:                         2.220e+04
# Df Residuals:                     952   BIC:                         2.222e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                5.284e+04   9420.984      5.609      0.000    3.44e+04    7.13e+04
# Total Population                     9.063e+05   1.25e+04     72.452      0.000    8.82e+05    9.31e+05
# Percent Less than Bachelor's Degree -6.615e+04   7331.150     -9.023      0.000   -8.05e+04   -5.18e+04
# Percent Female                      -4503.3361   8999.815     -0.500      0.617   -2.22e+04    1.32e+04
# ==============================================================================
# Omnibus:                     1547.185   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1401859.257
# Skew:                           9.644   Prob(JB):                         0.00
# Kurtosis:                     189.604   Cond. No.                         23.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# TASK 3a
# Build model with 3 predictors (using statsmodels)
X = X_train[["Total Population", "Percent Less than Bachelor's Degree", "Percent Age 29 and Under"]]
Y = X_train["Democratic"]
X = sm.add_constant(X)
results5 = sm.OLS(Y,X).fit()
print(results5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Democratic   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     2307.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:42:50   Log-Likelihood:                -11090.
# No. Observations:                 956   AIC:                         2.219e+04
# Df Residuals:                     952   BIC:                         2.221e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                6.317e+04   7110.849      8.883      0.000    4.92e+04    7.71e+04
# Total Population                      9.11e+05   1.25e+04     72.657      0.000    8.86e+05    9.36e+05
# Percent Less than Bachelor's Degree -6.853e+04   7144.359     -9.592      0.000   -8.25e+04   -5.45e+04
# Percent Age 29 and Under            -2.659e+04   8623.364     -3.083      0.002   -4.35e+04   -9663.924
# ==============================================================================
# Omnibus:                     1547.253   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1407270.883
# Skew:                           9.643   Prob(JB):                         0.00
# Kurtosis:                     189.968   Cond. No.                         20.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# TASK 3a
# The above model is the best performing model

# %%
# TASK 3a
# Build model with 4 predictors (using statsmodels)
X = X_train[["Total Population", "Percent Less than Bachelor's Degree", "Percent Age 29 and Under", "Percent Age 65 and Older"]]
Y = X_train["Democratic"]
X = sm.add_constant(X)
results5 = sm.OLS(Y,X).fit()
print(results5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Democratic   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     1737.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:43:42   Log-Likelihood:                -11088.
# No. Observations:                 956   AIC:                         2.219e+04
# Df Residuals:                     951   BIC:                         2.221e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                7.999e+04   1.12e+04      7.127      0.000     5.8e+04    1.02e+05
# Total Population                     9.064e+05   1.27e+04     71.137      0.000    8.81e+05    9.31e+05
# Percent Less than Bachelor's Degree -6.778e+04   7144.466     -9.487      0.000   -8.18e+04   -5.38e+04
# Percent Age 29 and Under             -4.93e+04   1.46e+04     -3.387      0.001   -7.79e+04   -2.07e+04
# Percent Age 65 and Older            -1.902e+04   9828.881     -1.936      0.053   -3.83e+04     264.646
# ==============================================================================
# Omnibus:                     1551.517   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1419278.661
# Skew:                           9.698   Prob(JB):                         0.00
# Kurtosis:                     190.761   Cond. No.                         32.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# TASK 3a
# Build model with 4 predictors (using statsmodels)
X = X_train[["Total Population", "Percent Less than Bachelor's Degree", "Percent Age 29 and Under", "Median Household Income"]]
Y = X_train["Democratic"]
X = sm.add_constant(X)
results5 = sm.OLS(Y,X).fit()
print(results5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Democratic   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     1730.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:44:22   Log-Likelihood:                -11089.
# No. Observations:                 956   AIC:                         2.219e+04
# Df Residuals:                     951   BIC:                         2.221e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                5.704e+04   1.03e+04      5.548      0.000    3.69e+04    7.72e+04
# Total Population                     9.107e+05   1.25e+04     72.590      0.000    8.86e+05    9.35e+05
# Percent Less than Bachelor's Degree -6.343e+04   9449.671     -6.712      0.000    -8.2e+04   -4.49e+04
# Percent Age 29 and Under            -2.645e+04   8626.314     -3.067      0.002   -4.34e+04   -9525.373
# Median Household Income              8347.4651   1.01e+04      0.825      0.410   -1.15e+04    2.82e+04
# ==============================================================================
# Omnibus:                     1544.653   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1395125.344
# Skew:                           9.611   Prob(JB):                         0.00
# Kurtosis:                     189.157   Cond. No.                         25.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# TASK 3a
# Build model with 4 predictors (using statsmodels)
X = X_train[["Total Population", "Percent Less than Bachelor's Degree", "Percent Age 29 and Under", "Percent Unemployed"]]
Y = X_train["Democratic"]
X = sm.add_constant(X)
results5 = sm.OLS(Y,X).fit()
print(results5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Democratic   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     1739.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:44:55   Log-Likelihood:                -11087.
# No. Observations:                 956   AIC:                         2.218e+04
# Df Residuals:                     951   BIC:                         2.221e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                6.311e+04   7096.184      8.893      0.000    4.92e+04     7.7e+04
# Total Population                     9.064e+05   1.27e+04     71.480      0.000    8.82e+05    9.31e+05
# Percent Less than Bachelor's Degree -7.373e+04   7503.215     -9.827      0.000   -8.85e+04    -5.9e+04
# Percent Age 29 and Under            -2.831e+04   8640.464     -3.277      0.001   -4.53e+04   -1.14e+04
# Percent Unemployed                   1.363e+04   6126.504      2.225      0.026    1611.362    2.57e+04
# ==============================================================================
# Omnibus:                     1555.725   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1433171.639
# Skew:                           9.752   Prob(JB):                         0.00
# Kurtosis:                     191.676   Cond. No.                         21.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# TASK 3a
# Build model with 4 predictors (using statsmodels)
X = X_train[["Total Population", "Percent Less than Bachelor's Degree", "Percent Age 29 and Under", 
             "Percent Less than High School Degree"]]
Y = X_train["Democratic"]
X = sm.add_constant(X)
results5 = sm.OLS(Y,X).fit()
print(results5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Democratic   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     1743.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:47:22   Log-Likelihood:                -11086.
# No. Observations:                 956   AIC:                         2.218e+04
# Df Residuals:                     951   BIC:                         2.221e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                 7.309e+04   8063.346      9.064      0.000    5.73e+04    8.89e+04
# Total Population                       9.06e+05   1.26e+04     71.641      0.000    8.81e+05    9.31e+05
# Percent Less than Bachelor's Degree   -8.35e+04   9185.356     -9.091      0.000   -1.02e+05   -6.55e+04
# Percent Age 29 and Under             -3.496e+04   9189.057     -3.805      0.000    -5.3e+04   -1.69e+04
# Percent Less than High School Degree  2.209e+04   8555.441      2.582      0.010    5303.160    3.89e+04
# ==============================================================================
# Omnibus:                     1545.374   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1399683.739
# Skew:                           9.620   Prob(JB):                         0.00
# Kurtosis:                     189.463   Cond. No.                         24.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# TASK 3a
# Build model with 4 predictors (using statsmodels)
X = X_train[["Total Population", "Percent Less than Bachelor's Degree", "Percent Age 29 and Under", 
             "Percent Rural"]]
Y = X_train["Democratic"]
X = sm.add_constant(X)
results5 = sm.OLS(Y,X).fit()
print(results5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Democratic   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     1729.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:47:09   Log-Likelihood:                -11090.
# No. Observations:                 956   AIC:                         2.219e+04
# Df Residuals:                     951   BIC:                         2.221e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                6.321e+04   7328.762      8.625      0.000    4.88e+04    7.76e+04
# Total Population                     9.109e+05   1.32e+04     69.243      0.000    8.85e+05    9.37e+05
# Percent Less than Bachelor's Degree -6.844e+04   7824.353     -8.748      0.000   -8.38e+04   -5.31e+04
# Percent Age 29 and Under             -2.67e+04   9653.342     -2.766      0.006   -4.56e+04   -7754.600
# Percent Rural                         -95.4550   3690.430     -0.026      0.979   -7337.782    7146.872
# ==============================================================================
# Omnibus:                     1547.407   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1407641.222
# Skew:                           9.645   Prob(JB):                         0.00
# Kurtosis:                     189.992   Cond. No.                         23.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 956 entries, 943 to 1131
# Data columns (total 20 columns):
# State                                    956 non-null object
# County                                   956 non-null object
# FIPS                                     956 non-null int64
# Total Population                         956 non-null float64
# Percent White, not Hispanic or Latino    956 non-null float64
# Percent Black, not Hispanic or Latino    956 non-null float64
# Percent Hispanic or Latino               956 non-null float64
# Percent Foreign Born                     956 non-null float64
# Percent Female                           956 non-null float64
# Percent Age 29 and Under                 956 non-null float64
# Percent Age 65 and Older                 956 non-null float64
# Median Household Income                  956 non-null float64
# Percent Unemployed                       956 non-null float64
# Percent Less than High School Degree     956 non-null float64
# Percent Less than Bachelor's Degree      956 non-null float64
# Percent more than Bachelor's Degree      956 non-null float64
# Percent Rural                            956 non-null float64
# Democratic                               956 non-null float64
# Republican                               956 non-null float64
# Party                                    956 non-null object
# dtypes: float64(16), int64(1), object(3)
# memory usage: 156.8+ KB

# %%
# TASK 3a

# The model with three predictor variables : 
# "Total Population", "Percent Less than Bachelor's Degree", "Percent Age 29 and Under" is the best performing model.
# The Adjusted R2 value of this model is 0.879.

# %%
# TASK 3b
# Build model with 1 predictor (using statsmodels)
X = X_train["Total Population"] 
Y = X_train["Republican"]
X = sm.add_constant(X)
results = sm.OLS(Y,X).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.841
# Model:                            OLS   Adj. R-squared:                  0.841
# Method:                 Least Squares   F-statistic:                     5040.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:55:59   Log-Likelihood:                -10779.
# No. Observations:                 956   AIC:                         2.156e+04
# Df Residuals:                     954   BIC:                         2.157e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             4604.9770    660.141      6.976      0.000    3309.481    5900.473
# Total Population  5.893e+05   8300.251     70.992      0.000    5.73e+05    6.06e+05
# ==============================================================================
# Omnibus:                      384.116   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           187327.756
# Skew:                          -0.303   Prob(JB):                         0.00
# Kurtosis:                      71.574   Cond. No.                         13.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Build model with 2 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino"]]
Y = X_train["Republican"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.844
# Model:                            OLS   Adj. R-squared:                  0.844
# Method:                 Least Squares   F-statistic:                     2581.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:56:35   Log-Likelihood:                -10769.
# No. Observations:                 956   AIC:                         2.154e+04
# Df Residuals:                     953   BIC:                         2.156e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                 -6861.5545   2633.806     -2.605      0.009    -1.2e+04   -1692.825
# Total Population                       6.005e+05   8592.795     69.888      0.000    5.84e+05    6.17e+05
# Percent White, not Hispanic or Latino  1.413e+04   3143.338      4.494      0.000    7958.052    2.03e+04
# ==============================================================================
# Omnibus:                      397.091   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           194518.087
# Skew:                          -0.412   Prob(JB):                         0.00
# Kurtosis:                      72.876   Cond. No.                         18.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Build model with 3 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino", "Percent Less than Bachelor's Degree"]]
Y = X_train["Republican"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     1797.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:58:01   Log-Likelihood:                -10751.
# No. Observations:                 956   AIC:                         2.151e+04
# Df Residuals:                     952   BIC:                         2.153e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                  1.683e+04   4690.355      3.588      0.000    7622.589     2.6e+04
# Total Population                       5.794e+05   9127.674     63.482      0.000    5.62e+05    5.97e+05
# Percent White, not Hispanic or Latino  1.299e+04   3091.872      4.201      0.000    6920.810    1.91e+04
# Percent Less than Bachelor's Degree   -3.007e+04   4967.656     -6.054      0.000   -3.98e+04   -2.03e+04
# ==============================================================================
# Omnibus:                      399.378   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           185851.593
# Skew:                          -0.449   Prob(JB):                         0.00
# Kurtosis:                      71.300   Cond. No.                         24.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Build model with 4 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino", "Percent Less than Bachelor's Degree", 
             "Percent Black, not Hispanic or Latino"]]
Y = X_train["Republican"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     1358.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:59:14   Log-Likelihood:                -10748.
# No. Observations:                 956   AIC:                         2.151e+04
# Df Residuals:                     951   BIC:                         2.153e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                  2.115e+04   4959.033      4.266      0.000    1.14e+04    3.09e+04
# Total Population                       5.818e+05   9145.438     63.620      0.000    5.64e+05       6e+05
# Percent White, not Hispanic or Latino  9301.6990   3388.363      2.745      0.006    2652.167     1.6e+04
# Percent Less than Bachelor's Degree   -3.066e+04   4957.465     -6.184      0.000   -4.04e+04   -2.09e+04
# Percent Black, not Hispanic or Latino -1.222e+04   4665.157     -2.620      0.009   -2.14e+04   -3068.322
# ==============================================================================
# Omnibus:                      395.991   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           180638.137
# Skew:                          -0.431   Prob(JB):                         0.00
# Kurtosis:                      70.336   Cond. No.                         24.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Build model with  5 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino", "Percent Less than Bachelor's Degree", 
             "Percent Black, not Hispanic or Latino", "Percent Hispanic or Latino"]]
Y = X_train["Republican"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     1087.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        16:59:43   Log-Likelihood:                -10747.
# No. Observations:                 956   AIC:                         2.151e+04
# Df Residuals:                     950   BIC:                         2.154e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                  1.534e+04   7201.695      2.130      0.033    1204.523    2.95e+04
# Total Population                       5.817e+05   9144.661     63.615      0.000    5.64e+05       6e+05
# Percent White, not Hispanic or Latino  1.586e+04   6795.557      2.334      0.020    2526.210    2.92e+04
# Percent Less than Bachelor's Degree    -3.15e+04   5014.344     -6.282      0.000   -4.13e+04   -2.17e+04
# Percent Black, not Hispanic or Latino -8068.3012   5973.164     -1.351      0.177   -1.98e+04    3653.820
# Percent Hispanic or Latino             8465.0120   7600.839      1.114      0.266   -6451.363    2.34e+04
# ==============================================================================
# Omnibus:                      394.557   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           180483.516
# Skew:                          -0.419   Prob(JB):                         0.00
# Kurtosis:                      70.307   Cond. No.                         31.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Build model with 5 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino", "Percent Less than Bachelor's Degree", 
             "Percent Black, not Hispanic or Latino", "Percent Foreign Born"]]
Y = X_train["Republican"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.851
# Method:                 Least Squares   F-statistic:                     1088.
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        17:01:28   Log-Likelihood:                -10747.
# No. Observations:                 956   AIC:                         2.151e+04
# Df Residuals:                     950   BIC:                         2.153e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                   2.81e+04   6788.023      4.140      0.000    1.48e+04    4.14e+04
# Total Population                       5.867e+05   9698.303     60.494      0.000    5.68e+05    6.06e+05
# Percent White, not Hispanic or Latino  4801.0568   4526.635      1.061      0.289   -4082.302    1.37e+04
# Percent Less than Bachelor's Degree   -3.352e+04   5310.371     -6.313      0.000   -4.39e+04   -2.31e+04
# Percent Black, not Hispanic or Latino -1.412e+04   4831.151     -2.923      0.004   -2.36e+04   -4640.443
# Percent Foreign Born                  -9279.9115   6194.113     -1.498      0.134   -2.14e+04    2875.813
# ==============================================================================
# Omnibus:                      379.502   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           170178.403
# Skew:                          -0.299   Prob(JB):                         0.00
# Kurtosis:                      68.360   Cond. No.                         25.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Build model with 6 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino", "Percent Less than Bachelor's Degree", 
             "Percent Black, not Hispanic or Latino", "Percent Foreign Born", "Percent Female"]]
Y = X_train["Republican"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     905.9
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        17:05:34   Log-Likelihood:                -10747.
# No. Observations:                 956   AIC:                         2.151e+04
# Df Residuals:                     949   BIC:                         2.154e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                  2.956e+04   8664.312      3.411      0.001    1.26e+04    4.66e+04
# Total Population                       5.869e+05   9748.064     60.212      0.000    5.68e+05    6.06e+05
# Percent White, not Hispanic or Latino  4841.8906   4531.371      1.069      0.286   -4050.775    1.37e+04
# Percent Less than Bachelor's Degree   -3.389e+04   5485.150     -6.179      0.000   -4.47e+04   -2.31e+04
# Percent Black, not Hispanic or Latino -1.417e+04   4837.248     -2.930      0.003   -2.37e+04   -4679.787
# Percent Foreign Born                  -9372.1295   6206.547     -1.510      0.131   -2.16e+04    2808.014
# Percent Female                        -1705.6687   6318.935     -0.270      0.787   -1.41e+04    1.07e+04
# ==============================================================================
# Omnibus:                      379.205   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           169688.657
# Skew:                          -0.297   Prob(JB):                         0.00
# Kurtosis:                      68.266   Cond. No.                         31.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Build model with 6 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino", "Percent Less than Bachelor's Degree", 
             "Percent Black, not Hispanic or Latino", "Percent Foreign Born", "Percent Age 29 and Under"]]
Y = X_train["Republican"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.851
# Method:                 Least Squares   F-statistic:                     906.6
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        17:06:51   Log-Likelihood:                -10746.
# No. Observations:                 956   AIC:                         2.151e+04
# Df Residuals:                     949   BIC:                         2.154e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                  3.267e+04   8687.552      3.761      0.000    1.56e+04    4.97e+04
# Total Population                       5.868e+05   9700.544     60.491      0.000    5.68e+05    6.06e+05
# Percent White, not Hispanic or Latino  3222.2024   4899.421      0.658      0.511   -6392.750    1.28e+04
# Percent Less than Bachelor's Degree   -3.444e+04   5422.690     -6.352      0.000   -4.51e+04   -2.38e+04
# Percent Black, not Hispanic or Latino -1.465e+04   4873.155     -3.007      0.003   -2.42e+04   -5091.505
# Percent Foreign Born                  -9452.1810   6198.426     -1.525      0.128   -2.16e+04    2712.024
# Percent Age 29 and Under              -5764.4646   6837.951     -0.843      0.399   -1.92e+04    7654.788
# ==============================================================================
# Omnibus:                      381.459   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           169937.994
# Skew:                          -0.321   Prob(JB):                         0.00
# Kurtosis:                      68.313   Cond. No.                         31.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Build model with 6 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino", "Percent Less than Bachelor's Degree", 
             "Percent Black, not Hispanic or Latino", "Percent Foreign Born", "Percent Age 65 and Older"]]
Y = X_train["Republican"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     905.8
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        17:07:26   Log-Likelihood:                -10747.
# No. Observations:                 956   AIC:                         2.151e+04
# Df Residuals:                     949   BIC:                         2.154e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                   2.81e+04   6795.835      4.135      0.000    1.48e+04    4.14e+04
# Total Population                       5.867e+05   9744.603     60.207      0.000    5.68e+05    6.06e+05
# Percent White, not Hispanic or Latino  4799.7460   4645.229      1.033      0.302   -4316.362    1.39e+04
# Percent Less than Bachelor's Degree   -3.352e+04   5381.824     -6.229      0.000   -4.41e+04    -2.3e+04
# Percent Black, not Hispanic or Latino -1.412e+04   4834.737     -2.921      0.004   -2.36e+04   -4633.264
# Percent Foreign Born                  -9279.6331   6201.253     -1.496      0.135   -2.14e+04    2890.120
# Percent Age 65 and Older                  5.5281   4354.451      0.001      0.999   -8539.938    8550.994
# ==============================================================================
# Omnibus:                      379.507   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           170179.702
# Skew:                          -0.299   Prob(JB):                         0.00
# Kurtosis:                      68.360   Cond. No.                         26.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Build model with 6 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino", "Percent Less than Bachelor's Degree", 
             "Percent Black, not Hispanic or Latino", "Percent Foreign Born", "Median Household Income"]]
Y = X_train["Republican"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     923.6
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        17:07:53   Log-Likelihood:                -10739.
# No. Observations:                 956   AIC:                         2.149e+04
# Df Residuals:                     949   BIC:                         2.153e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                  1.171e+04   7891.865      1.484      0.138   -3778.993    2.72e+04
# Total Population                       5.882e+05   9630.937     61.078      0.000    5.69e+05    6.07e+05
# Percent White, not Hispanic or Latino  1709.0602   4558.048      0.375      0.708   -7235.958    1.07e+04
# Percent Less than Bachelor's Degree   -1.778e+04   6585.029     -2.700      0.007   -3.07e+04   -4855.941
# Percent Black, not Hispanic or Latino -1.415e+04   4793.730     -2.951      0.003   -2.36e+04   -4738.254
# Percent Foreign Born                  -1.535e+04   6332.116     -2.425      0.016   -2.78e+04   -2926.267
# Median Household Income                2.892e+04   7253.696      3.986      0.000    1.47e+04    4.32e+04
# ==============================================================================
# Omnibus:                      368.811   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           157763.700
# Skew:                          -0.203   Prob(JB):                         0.00
# Kurtosis:                      65.932   Cond. No.                         29.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Build model with 7 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino", "Percent Less than Bachelor's Degree", 
             "Percent Black, not Hispanic or Latino", "Percent Foreign Born", "Median Household Income", "Percent Unemployed"]]
Y = X_train["Republican"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     804.2
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        17:09:02   Log-Likelihood:                -10732.
# No. Observations:                 956   AIC:                         2.148e+04
# Df Residuals:                     948   BIC:                         2.152e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                  3209.2356   8170.902      0.393      0.695   -1.28e+04    1.92e+04
# Total Population                       5.852e+05   9603.689     60.931      0.000    5.66e+05    6.04e+05
# Percent White, not Hispanic or Latino  3680.7319   4559.404      0.807      0.420   -5266.960    1.26e+04
# Percent Less than Bachelor's Degree   -1.907e+04   6550.938     -2.911      0.004   -3.19e+04   -6210.705
# Percent Black, not Hispanic or Latino -1.729e+04   4837.706     -3.574      0.000   -2.68e+04   -7796.197
# Percent Foreign Born                  -1.562e+04   6290.828     -2.484      0.013    -2.8e+04   -3279.053
# Median Household Income                3.701e+04   7532.410      4.914      0.000    2.22e+04    5.18e+04
# Percent Unemployed                     1.717e+04   4651.545      3.692      0.000    8044.176    2.63e+04
# ==============================================================================
# Omnibus:                      368.166   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           157611.370
# Skew:                          -0.194   Prob(JB):                         0.00
# Kurtosis:                      65.902   Cond. No.                         30.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Build model with 8 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino", "Percent Less than Bachelor's Degree", 
             "Percent Black, not Hispanic or Latino", "Percent Foreign Born", "Median Household Income", 
             "Percent Unemployed", "Percent Less than High School Degree"]]
Y = X_train["Republican"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     705.2
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        17:10:04   Log-Likelihood:                -10731.
# No. Observations:                 956   AIC:                         2.148e+04
# Df Residuals:                     947   BIC:                         2.152e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                  4647.3232   8211.221      0.566      0.572   -1.15e+04    2.08e+04
# Total Population                        5.88e+05   9747.924     60.317      0.000    5.69e+05    6.07e+05
# Percent White, not Hispanic or Latino  5288.1001   4660.776      1.135      0.257   -3858.543    1.44e+04
# Percent Less than Bachelor's Degree   -2.669e+04   8044.057     -3.319      0.001   -4.25e+04   -1.09e+04
# Percent Black, not Hispanic or Latino -1.824e+04   4868.202     -3.746      0.000   -2.78e+04   -8683.155
# Percent Foreign Born                   -2.13e+04   7184.288     -2.965      0.003   -3.54e+04   -7201.747
# Median Household Income                4.006e+04   7754.333      5.166      0.000    2.48e+04    5.53e+04
# Percent Unemployed                     1.678e+04   4653.615      3.606      0.000    7650.319    2.59e+04
# Percent Less than High School Degree   1.316e+04   8069.637      1.631      0.103   -2673.414     2.9e+04
# ==============================================================================
# Omnibus:                      367.143   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           152799.305
# Skew:                          -0.200   Prob(JB):                         0.00
# Kurtosis:                      64.934   Cond. No.                         33.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Build model with 8 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino", "Percent Less than Bachelor's Degree", 
             "Percent Black, not Hispanic or Latino", "Percent Foreign Born", "Median Household Income", 
             "Percent Unemployed", "Percent more than Bachelor's Degree"]]
Y = X_train["Republican"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     804.2
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        17:10:51   Log-Likelihood:                -10732.
# No. Observations:                 956   AIC:                         2.148e+04
# Df Residuals:                     948   BIC:                         2.152e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                 -4216.0837   3918.177     -1.076      0.282   -1.19e+04    3473.219
# Total Population                       5.852e+05   9603.689     60.931      0.000    5.66e+05    6.04e+05
# Percent White, not Hispanic or Latino  3680.7319   4559.404      0.807      0.420   -5266.960    1.26e+04
# Percent Less than Bachelor's Degree   -1.164e+04   2720.752     -4.279      0.000    -1.7e+04   -6302.010
# Percent Black, not Hispanic or Latino -1.729e+04   4837.706     -3.574      0.000   -2.68e+04   -7796.197
# Percent Foreign Born                  -1.562e+04   6290.828     -2.484      0.013    -2.8e+04   -3279.053
# Median Household Income                3.701e+04   7532.410      4.914      0.000    2.22e+04    5.18e+04
# Percent Unemployed                     1.717e+04   4651.545      3.692      0.000    8044.176    2.63e+04
# Percent more than Bachelor's Degree    7425.3193   4661.648      1.593      0.112   -1723.022    1.66e+04
# ==============================================================================
# Omnibus:                      368.166   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           157611.370
# Skew:                          -0.194   Prob(JB):                         0.00
# Kurtosis:                      65.902   Cond. No.                     1.87e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.78e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Build model with 8 predictors (using statsmodels)
X = X_train[["Total Population", "Percent White, not Hispanic or Latino", "Percent Less than Bachelor's Degree", 
             "Percent Black, not Hispanic or Latino", "Percent Foreign Born", "Median Household Income", 
             "Percent Unemployed", "Percent Rural"]]
Y = X_train["Republican"]
X = sm.add_constant(X)
results3 = sm.OLS(Y,X).fit()
print(results3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Republican   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                     724.8
# Date:                Fri, 08 Nov 2019   Prob (F-statistic):               0.00
# Time:                        17:12:30   Log-Likelihood:                -10719.
# No. Observations:                 956   AIC:                         2.146e+04
# Df Residuals:                     947   BIC:                         2.150e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                  2244.2984   8070.646      0.278      0.781   -1.36e+04    1.81e+04
# Total Population                       5.776e+05   9601.409     60.159      0.000    5.59e+05    5.96e+05
# Percent White, not Hispanic or Latino  6045.7196   4526.720      1.336      0.182   -2837.842    1.49e+04
# Percent Less than Bachelor's Degree   -7143.7359   6890.177     -1.037      0.300   -2.07e+04    6378.045
# Percent Black, not Hispanic or Latino -1.857e+04   4783.832     -3.883      0.000    -2.8e+04   -9186.675
# Percent Foreign Born                  -2.066e+04   6292.327     -3.284      0.001    -3.3e+04   -8315.830
# Median Household Income                3.557e+04   7443.433      4.779      0.000     2.1e+04    5.02e+04
# Percent Unemployed                     1.318e+04   4661.423      2.827      0.005    4031.150    2.23e+04
# Percent Rural                         -1.234e+04   2455.541     -5.025      0.000   -1.72e+04   -7519.895
# ==============================================================================
# Omnibus:                      363.951   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           159051.454
# Skew:                           0.091   Prob(JB):                         0.00
# Kurtosis:                      66.189   Cond. No.                         32.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# TASK 3b

# The model with EIGHT predictor variables : 
#              "Total Population", "Percent White, not Hispanic or Latino", "Percent Less than Bachelor's Degree", 
#             "Percent Black, not Hispanic or Latino", "Percent Foreign Born", "Median Household Income", 
#             "Percent Unemployed", "Percent Rural" 
# is the best performing model.
# The Adjusted R2 value of this model is 0.858.
